# %% [markdown]
# # Lab2: Text Pre-processing and Regular Expressions

# %% [markdown]
#  In this lab, you will learn essential techniques for preparing and cleaning text data using various pre-processing steps. Additionally, you will gain hands-on experience with regular expressions, a powerful tool for pattern matching and text manipulation in natural language processing (NLP) tasks.

# %% [markdown]
# _____________________________________________________________________________________________

# %% [markdown]
# ## Regular Expressions

# %% [markdown]
# Regular expressions (regex) extremely useful in extracting information from any text by searching for one or more matches of a specific search pattern
#
# https://www.regexpal.com/

# %% [markdown]
# #### Regular Expressions use cases
#
# - Data pre-processing
# - Pattern matching
# - Text feature Engineering
# - Web scraping
# - Data validation
# - Data extraction
#
# An example use case is extracting all hashtags from a tweet, or getting email addresses or phone numbers from large unstructured text content.

# %% [markdown]
# ## Regular Expressions with Python
#
# Python provides a convenient built-in module for managing regular expressions:
#
# > import re
#
# We can import it as we import any other Python library.

# %% [markdown]
# ### Important symbols in Regular Expression (For your reference)
#
# Let’s start with the basic regular expression characters and some examples:
#
# - (^) : Matches the expression to its right, at the start of a string before it finds a line break.
# - ($) : Matches the expression to its left, at the end of a string before it finds a line break.
# - (.) : Matches any character except newline.
# - (a) : Matches exactly one character.
# - (ab) : Matches the string ab.
#
# ----------------------------------------------------------------------------
# Quantifiers:
#
# - (a|b) : Matches expression a or b. If a is matched first, b is not checked;
# - (+) : Matches the expression to its left 1 or more times;
# - (*) : Matches the expression to its left 0 or more times;
# - (?) : Matches the expression to its left 0 or 1 times.
# ----------------------------------------------------------------------------
# Character Classes:
#
# - \w : Matches alphanumeric characters, that is a-z, A-Z, 0–9, and underscore(_);
# - \W : Matches non-alphanumeric characters, that is except a-z, A-Z, 0–9, and _;
# - \d : Matches digits, from 0–9;
# - \D : Matches any non-digits;
# - \s : Matches whitespace characters, which also include the \t, \n, \r, and space characters;
# - \S : Matches non-whitespace characters.
# - \n : Matches a newline character;
# - \t : Matches a tab character;
# - \b : Matches the word boundary (or empty string) at the start and end of a word;
# - \B : Matches where \b does not, that is non-word boundary.
#
# ----------------------------------------------------------------------------
# Sets:
#
# - [abc] : Matches either a, b, or c. It does not match abc;
# - [a-z] : Matches any alphabet from a to z;
# - [A-Z] : Matches any alphabets in capital from A to Z;
# - [a\-p] : Matches a, -, or p. It matches - because \ escapes it;
# - [-z] : Matches - or z;
# - [a-z0–9] : Matches characters from a to z or from 0 to 9.
# - [(+*)] : Special characters become literal inside a set, so this matches (, +, *, or );
# - [^ab5] : Adding ^ excludes any character in the set. Here, it matches characters that are not a, b, or 5;
# ----------------------------------------------------------------------------
#
#
# ### Regular Expression functions

# %% [markdown]
# #### search
#
# Search for pattern occurrences in a string using the search function of the **re module**. This function returns a match object, containing the first matched substring (or None, if it doesn’t exist) and its position inside the original string.

# %%
import re

text = 'I am enjoying the NLP course.'

print(re.search("I", text)) #r"I" means it's a raw string literal
print(re.search("se.$", text)) #$ Search at the end of the string
print(re.search("am", text))
print(re.search("m", text))
print(re.search("AI", text))
# Out:
# <re.Match object; span=(0, 1), match='I'>
# <re.Match object; span=(26, 29), match='se.'>
# <re.Match object; span=(2, 4), match='am'>
# <re.Match object; span=(3, 4), match='m'>
# None

# %% [markdown]
# #### match
#
# The match function is similar to search, but it only tries to match the pattern at the beginning of the target string.

# %%
import re
re.match?

# %%
import re

text = 'I am enjoying the NLP course.'

print(re.search("I.*", text)) #global
print(re.match("I.*", text)) #local >> search at the start of the string

print(re.search("enjoying.*", text))
print(re.match("enjoying.*", text))
# Out:
# <re.Match object; span=(0, 29), match='I am enjoying the NLP course.'>
# <re.Match object; span=(0, 29), match='I am enjoying the NLP course.'>
# <re.Match object; span=(5, 29), match='enjoying the NLP course.'>
# None

# %%
import re

text = '1999 was the year I was born.'

print(re.search(r"[a-zA-Z]+", text))
print(re.match(r"[a-zA-Z]+", text))
# Out:
# <re.Match object; span=(5, 8), match='was'>
# None

# %% [markdown]
# Search does a global search, whereas match does a local search!
#
# **Match** is often used when you need to check if the string starts with a specific pattern.
#
#
# **Search** is used when you want to find a pattern anywhere within the string.

# %% [markdown]
# #### findall
#
# The findall function looks for all the pattern matches in the target string (whereas search and match look only for the first occurrence).
#
# - `re.findall()` returns a list of all matches.
#
# - `re.finditer()` returns an iterator of match objects.
#
# - `re.search() and re.match()` both return a single match object for the first occurrence (but differ in where they start matching: match() matches only at the start of the string, search() anywhere).

# %%
import re

text1 = "a 1 b 2 c 3"
text2 = "a1 b2 c 3"
text3 = "a 1 b 222 c 3"

print(re.findall(r"\d+", text1)) #match any digit
print(re.findall(r"\d+", text2))
print(re.findall(r"\d+", text3))
# Out:
# ['1', '2', '3']
# ['1', '2', '3']
# ['1', '222', '3']

# %% [markdown]
# #### sub
#
# The sub is a function that finds patterns in the target string and substitute them with another string.
#
# flags=re.I --> non-case-sensitive
#
# count = specify number of matches you want to replace

# %%
import re

re.sub?

# %%
import re

text = 'I am enjoying the Math course.'

print(re.sub(r"Math", "NLP", text, count=1, flags=re.I)) #flags=re.I >> Ignore the case (no matter if M or m)
                                                 # count = 1 >> number of word I need it to change. count= 0 by default
# Out:
# I am enjoying the NLP course.

# %% [markdown]
# __________________________________________________________________________

# %% [markdown]
# ## Text pre-processing steps

# %% [markdown]
# Text preprocessing involves transforming text into a clean and consistent format that can then be fed into a model for further analysis and learning. Raw text data might contain unwanted or unimportant text due to which our results might not give efficient accuracy, and might make it hard to understand and analyze.

# %% [markdown]
# **The various text preprocessing steps are:**
#
# 1. Tokenization.
# 2. Lower casing.
# 3. Stop words removal.
# 4. Stemming.
# 5. Lemmatization.
#
# Before implementing the pre-processing, let us understand the concept first.

# %% [markdown]
# ### Tokenization
#
# Tokenization is used in NLP to split paragraphs and sentences into smaller units that can be more easily assigned meaning.
#
# The first step of the NLP process is gathering the data (a sentence) and breaking it into understandable parts (words).

# %% [markdown]
# - **Sentence Tokenization**

# %%
# !pip install nltk
import nltk
nltk.download('punkt') #Punkt is a pretrained unsupervised machine learning tokenizer model
nltk.download('punkt_tab') #newer NLTK versions split the tokenizer data into 'punkt_tab'
# Out:
# Requirement already satisfied: nltk in c:\users\jaber\appdata\local\programs\python\python313\lib\site-packages (3.10.3)
# Requirement already satisfied: defusedxml in c:\users\jaber\appdata\local\programs\python\python313\lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in c:\users\jaber\appdata\local\programs\python\python313\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\jaber\appdata\local\programs\python\python313\lib\site-packages (from nltk) (1.6.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\jaber\appdata\local\programs\python\python313\lib\site-packages (from nltk) (2026.9.10)
# Requirement already satisfied: tqdm in c:\users\jaber\appdata\local\programs\python\python313\lib\site-packages (from nltk) (4.70.1)
# Requirement already satisfied: colorama in c:\users\jaber\appdata\local\programs\python\python313\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: cloudpickle>=3.0 in c:\users\jaber\appdata\local\programs\python\python313\lib\site-packages (from joblib->nltk) (3.1.2)
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# [nltk_data] Downloading package punkt to C:\Users\jaber/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\jaber/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import nltk

text = "I'm enjoying the NLP course! I am also learning new concepts."

print(nltk.sent_tokenize(text))
# Out:
# ["I'm enjoying the NLP course!", 'I am also learning new concepts.']

# %% [markdown]
# - **Word Tokenzitaion**

# %%
import nltk

text = "I'm enjoying the NLP course!"

print(nltk.word_tokenize(text)) #I'm is tokenized to two tokens [I,m], course! is also tokenized to two tokens [course,!]
# Out:
# ['I', "'m", 'enjoying', 'the', 'NLP', 'course', '!']

# %%
text = "I'm enjoying the NLP course!"
text.split()
# Out:
# ["I'm", 'enjoying', 'the', 'NLP', 'course!']

# %% [markdown]
# ### Lower Casting

# %% [markdown]
# Converting a word to lower case (NLP -> nlp). Words like Book and book mean the same but when not converted to the lower case those two are represented as two different words in the vector space model (resulting in more dimensions).

# %%
text = "I'm enjoying the NLP course!"
text = text.lower()
print(text)
# Out:
# i'm enjoying the nlp course!

# %% [markdown]
# ### Stemming

# %% [markdown]
# Stemming is basically removing the suffix from a word and reduce it to its root word. For example: “Flying” is a word and its suffix is “ing”, if we remove “ing” from “Flying” then we will get base word or root word which is “Fly”. We uses these suffix to create a new word from original stem word.

# %% [markdown]
# https://www.nltk.org/howto/stem.html

# %% [markdown]
# #### What is PorterStemmer?
#
# It is one of the most popular stemming methods proposed in 1980. It is based on the idea that the suffixes in the English language are made up of a combination of smaller and simpler suffixes. This stemmer is known for its speed and simplicity. The main applications of Porter Stemmer include data mining and Information retrieval. However, its applications are only limited to English words. Also, the group of stems is mapped on to the same stem and the output stem is not necessarily a meaningful word. The algorithms are fairly lengthy in nature and are known to be the oldest stemmer.
#
# > Advantage: It produces the best output as compared to other stemmers and it has less error rate.
#
# > Limitation:  Morphological variants produced are not always real words.

# %%
import nltk
from nltk.stem import PorterStemmer

ps = PorterStemmer() # create a PorterStemmer object

words = ['run','runner','running','ran','runs','easily','fairly']

for word in words:
    print(word + ' --> ' + ps.stem(word))
# Out:
# run --> run
# runner --> runner
# running --> run
# ran --> ran
# runs --> run
# easily --> easili
# fairly --> fairli

# %% [markdown]
# #### What is SnowballStemmer?
#
# It is a stemming algorithm which is also known as the Porter2 stemming algorithm as it is a better version of the Porter Stemmer since some issues of it were fixed in this stemmer.
#
# > Advantage: It is slightly faster computation time than porter, with a reasonably large community around it.

# %%
import nltk
from nltk.stem.snowball import SnowballStemmer

sn = SnowballStemmer(language='english')

words = ['run','runner','running','ran','runs','easily','fairly']

for word in words:
    print(word+' --> '+sn.stem(word))
# Out:
# run --> run
# runner --> runner
# running --> run
# ran --> ran
# runs --> run
# easily --> easili
# fairly --> fair

# %% [markdown]
# #### Comparing between porter and snowball

# %%
words = ['generous','generation','generously','generate']

for word in words:
    print(word+' --> '+ps.stem(word))
    print(word+' --> '+sn.stem(word))
    print('---------------------------------------')
# Out:
# generous --> gener
# generous --> generous
# ---------------------------------------
# generation --> gener
# generation --> generat
# ---------------------------------------
# generously --> gener
# generously --> generous
# ---------------------------------------
# generate --> gener
# generate --> generat
# ---------------------------------------

# %% [markdown]
# **Note**: Spacy does not provide stemming

# %% [markdown]
# ### Lemmatization

# %% [markdown]
# Lemmatization is the process of grouping together the different inflected forms of a word so they can be analyzed as a single item. Lemmatization is similar to stemming but it brings context to the words. So it links words with similar meanings to one word.
#
# > One major difference with stemming is that lemmatize takes a part of speech parameter (pos) If not supplied, the default is “noun.”

# %% [markdown]
# | Part of Speech          | Description                | Example Words           |
# | ----------------------- | -------------------------- | ----------------------- |
# | **Noun (N)**            | Person, place, thing, idea | dog, city, love, Python |
# | **Verb (V)**            | Action or state            | run, eat, is, was, jump |
# | **Adjective (ADJ)**     | Describes a noun           | happy, blue, fast       |
# | **Adverb (ADV)**        | Describes a verb/adjective | quickly, very, well     |
# | **Pronoun (PRON)**      | Replaces a noun            | he, she, it, they       |
# | **Preposition (ADP)**   | Shows relationship         | in, on, under, with     |
# | **Conjunction (CONJ)**  | Connects words/clauses     | and, but, or            |
# | **Determiner (DET)**    | Introduces a noun          | a, an, the              |
# | **Interjection (INTJ)** | Expresses emotion          | wow, oh, hey            |

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\jaber/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\jaber/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import nltk
from nltk.stem import WordNetLemmatizer

text = 'I am enjoying AI courses. I am taking NLP course.'
lemmatizer = WordNetLemmatizer()

for word in nltk.word_tokenize(text):
    print(f"{word}: ", lemmatizer.lemmatize(word))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[17], line 8
#       4 text = 'I am enjoying AI courses. I am taking NLP course.'
#       5 lemmatizer = WordNetLemmatizer()
#       6
#       7 for word in nltk.word_tokenize(text):
# ----> 8     print(f"{word}: ", lemmatizer.lemmatize(word))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\stem\wordnet.py:85, in WordNetLemmatizer.lemmatize(self, word, pos)
#      60 def lemmatize(self, word: str, pos: str = "n") -> str:
#      61     """Lemmatize `word` by picking the shortest of the possible lemmas,
#      62     using the wordnet corpus reader's built-in _morphy function.
#      63     Returns the input word unchanged if it cannot be found in WordNet.
#    (...)     83     :return: The shortest lemma of `word`, for the given `pos`.
#      84     """
# ---> 85     lemmas = self._morphy(word, pos)
#      86     return min(lemmas, key=len) if lemmas else word
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\stem\wordnet.py:41, in WordNetLemmatizer._morphy(self, form, pos, check_exceptions)
#      31 """
#      32 _morphy() is WordNet's _morphy lemmatizer.
#      33 It returns a list of all lemmas found in WordNet.
#    (...)     37 ['us', 'u']
#      38 """
#      39 from nltk.corpus import wordnet as wn
# ---> 41 return wn._morphy(form, pos, check_exceptions)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\corpus\util.py:129, in LazyCorpusLoader.__getattr__(self, attr)
#     124 if attr.startswith("__") and attr.endswith("__"):
#     125     raise AttributeError(
#     126         f"{type(self).__name__} object has no attribute {attr!r}"
#     127     )
# --> 129 self.__load()
#     130 # This looks circular, but its not, since __load() changes our
#     131 # __class__ to something new:
#     132 return getattr(self, attr)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\corpus\util.py:90, in LazyCorpusLoader.__load(self)
#      87             raise e
#      89 # Load the corpus.
# ---> 90 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#      92 # This is where the magic happens!  Transform ourselves into
#      93 # the corpus by modifying our own __dict__ and __class__ to
#      94 # match that of the corpus.
#      96 args, kwargs = self.__args, self.__kwargs
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\corpus\reader\wordnet.py:1163, in WordNetCorpusReader.__init__(self, root, omw_reader)
#    1157 def __init__(self, root, omw_reader):
#    1158     """
#    1159     Construct a new wordnet corpus reader, with the given root
#    1160     directory.
#    1161     """
# -> 1163     super().__init__(root, self._FILES, encoding=self._ENCODING)
#    1165     # A index that provides the file offset
#    1166     # Map from lemma -> pos -> synset_index -> offset
#    1167     self._lemma_pos_offset_map = defaultdict(dict)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\corpus\reader\api.py:84, in CorpusReader.__init__(self, root, fileids, encoding, tagset)
#      74 # Defense in depth (CWE-73 / CWE-59; GHSA-3gq4-3j92-5w49, GHSA-p4rw):
#      75 # validate the raw string root against the NLTK data sandbox before it
#      76 # becomes a PathPointer, so a reader cannot be pointed outside the
#    (...)     81 # The ``str`` test also covers ``FileSystemPathPointer`` (a ``str``
#      82 # subclass), so a pointer root is validated too.
#      83 if pathsec.ENFORCE and isinstance(root, str):
# ---> 84     pathsec.validate_path(root, context="CorpusReader.__init__")
#      86 # Convert the root to a path pointer, if necessary.
#      87 if isinstance(root, str) and not isinstance(root, PathPointer):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\pathsec.py:210, in validate_path(path_input, context, required_root)
#     208 msg = f"Security Violation [{context}]: Unauthorized path {target}"
#     209 if ENFORCE:
# --> 210     raise PermissionError(msg)
#     211 else:
#     212     warnings.warn(msg, RuntimeWarning, stacklevel=3)
#
# PermissionError: Security Violation [CorpusReader.__init__]: Unauthorized path C:\Users\jaber\AppData\Local\Packages\Claude_pzs8sxrjxfjjc\LocalCache\Roaming\nltk_data\corpora\wordnet

# %%
# Changing pos to verb
for word in nltk.word_tokenize(text):
    print(f"{word}: ", lemmatizer.lemmatize(word, pos='v'))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Changing pos to verb
#       2 for word in nltk.word_tokenize(text):
# ----> 3     print(f"{word}: ", lemmatizer.lemmatize(word, pos='v'))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\stem\wordnet.py:85, in WordNetLemmatizer.lemmatize(self, word, pos)
#      60 def lemmatize(self, word: str, pos: str = "n") -> str:
#      61     """Lemmatize `word` by picking the shortest of the possible lemmas,
#      62     using the wordnet corpus reader's built-in _morphy function.
#      63     Returns the input word unchanged if it cannot be found in WordNet.
#    (...)     83     :return: The shortest lemma of `word`, for the given `pos`.
#      84     """
# ---> 85     lemmas = self._morphy(word, pos)
#      86     return min(lemmas, key=len) if lemmas else word
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\stem\wordnet.py:41, in WordNetLemmatizer._morphy(self, form, pos, check_exceptions)
#      31 """
#      32 _morphy() is WordNet's _morphy lemmatizer.
#      33 It returns a list of all lemmas found in WordNet.
#    (...)     37 ['us', 'u']
#      38 """
#      39 from nltk.corpus import wordnet as wn
# ---> 41 return wn._morphy(form, pos, check_exceptions)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\corpus\util.py:129, in LazyCorpusLoader.__getattr__(self, attr)
#     124 if attr.startswith("__") and attr.endswith("__"):
#     125     raise AttributeError(
#     126         f"{type(self).__name__} object has no attribute {attr!r}"
#     127     )
# --> 129 self.__load()
#     130 # This looks circular, but its not, since __load() changes our
#     131 # __class__ to something new:
#     132 return getattr(self, attr)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\corpus\util.py:90, in LazyCorpusLoader.__load(self)
#      87             raise e
#      89 # Load the corpus.
# ---> 90 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#      92 # This is where the magic happens!  Transform ourselves into
#      93 # the corpus by modifying our own __dict__ and __class__ to
#      94 # match that of the corpus.
#      96 args, kwargs = self.__args, self.__kwargs
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\corpus\reader\wordnet.py:1163, in WordNetCorpusReader.__init__(self, root, omw_reader)
#    1157 def __init__(self, root, omw_reader):
#    1158     """
#    1159     Construct a new wordnet corpus reader, with the given root
#    1160     directory.
#    1161     """
# -> 1163     super().__init__(root, self._FILES, encoding=self._ENCODING)
#    1165     # A index that provides the file offset
#    1166     # Map from lemma -> pos -> synset_index -> offset
#    1167     self._lemma_pos_offset_map = defaultdict(dict)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\corpus\reader\api.py:84, in CorpusReader.__init__(self, root, fileids, encoding, tagset)
#      74 # Defense in depth (CWE-73 / CWE-59; GHSA-3gq4-3j92-5w49, GHSA-p4rw):
#      75 # validate the raw string root against the NLTK data sandbox before it
#      76 # becomes a PathPointer, so a reader cannot be pointed outside the
#    (...)     81 # The ``str`` test also covers ``FileSystemPathPointer`` (a ``str``
#      82 # subclass), so a pointer root is validated too.
#      83 if pathsec.ENFORCE and isinstance(root, str):
# ---> 84     pathsec.validate_path(root, context="CorpusReader.__init__")
#      86 # Convert the root to a path pointer, if necessary.
#      87 if isinstance(root, str) and not isinstance(root, PathPointer):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\pathsec.py:210, in validate_path(path_input, context, required_root)
#     208 msg = f"Security Violation [{context}]: Unauthorized path {target}"
#     209 if ENFORCE:
# --> 210     raise PermissionError(msg)
#     211 else:
#     212     warnings.warn(msg, RuntimeWarning, stacklevel=3)
#
# PermissionError: Security Violation [CorpusReader.__init__]: Unauthorized path C:\Users\jaber\AppData\Local\Packages\Claude_pzs8sxrjxfjjc\LocalCache\Roaming\nltk_data\corpora\wordnet

# %% [markdown]
# You may go through Spacy's lemmatizer: https://spacy.io/api/lemmatizer

# %% [markdown]
# ### Stop Words Removal

# %% [markdown]
# The words which are generally filtered out before processing a natural language are called stop words. These are actually the most common words in any language (like articles, prepositions, pronouns, conjunctions, etc) and does not add much information to the text. Examples of a few stop words in English are “the”, “a”, “an”, “so”, “what”.

# %% [markdown]
# #### Why do we need to remove stopwords?

# %% [markdown]
# By removing these words, we remove the low-level information from our text in order to give more focus to the important information. In order words, we can say that the removal of such words does not show any negative consequences on the model we train for our task.
#
# - reduces the dataset size
# - reduces the training time

# %% [markdown]
# #### Do we always remove stopwords? **NO!**

# %% [markdown]
# We do not always remove the stop words. The removal of stop words is highly dependent on the task we are performing and the goal we want to achieve. For example, if we are training a model that can perform the sentiment analysis task, we might not remove the stop words.
#
# Movie review: “The movie was not good at all.”
#
# Text after removal of stop words: “movie good”

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
print(len(nlp.Defaults.stop_words))
# Out:
# {'below', 'something', 'almost', 'out', 'used', 'four', 'too', 'yourself', 'therefore', 'and', 'off', 'over', 'get', 'one', 'why', 'did', 'me', 'herself', 'being', 'hereafter', 'my', 'whether', 'toward', 'does', 'during', 'you', 'may', 'perhaps', 'here', 'third', 'how', '’re', 'amount', 'less', 'our', 'front', 'beyond', 'that', 'within', 'whenever', 'thus', 'also', 'since', 'into', 'now', 'fifty', 'otherwise', 'hence', 'above', 'put', 'other', 'us', 're', 'who', 'everything', 'yourselves', '‘ve', 'themselves', 'see', "'re", 'behind', 'we', 'someone', 'never', 'against', 'namely', 'both', 'more', 'twenty', 'as', 'her', 'because', 'not', 'two', 'for', 'of', 'was', 'in', 'six', 'a', 'give', 'even', 'his', 'will', 'becoming', 'when', 'per', 'their', 'together', 'every', 'ever', 'no', 'become', 'has', 'although', 'under', 'towards', 'neither', 'whatever', 'wherever', 'whereupon', 'anyone', 'formerly', 'moreover', 'these', 'been', 'bottom', 'mine', 'along', 'sometime', 'many', 'done', 'there', 'than', 'three', 'next', 'once', 'thereafter', 'alone', 'full', 'anyhow', 'latterly', 'quite', 'those', 'from', 'which', 'everywhere', 'another', 'any', 'either', 'some', 'just', 'therein', 'due', 'side', 'each', 'itself', 'across', 'several', 'them', 'serious', 'but', 'nevertheless', 'hereby', 'very', 'whereby', 'nowhere', 'name', 'whoever', 'anywhere', 'top', 'thereby', 'others', 'move', 'former', 'it', 'while', '‘m', 'only', 'then', 'via', 'thru', 'n‘t', 'they', 'have', 'or', 'through', 'sometimes', 'really', "'m", 'whereas', 'again', 'doing', 'using', 'ten', 'except', 'were', 'down', 'anyway', 'fifteen', 'hereupon', 'five', '’s', 'everyone', 'on', 'still', 'call', 'keep', 'can', 'nothing', 'herein', 'however', 'hers', 'most', 'somewhere', "n't", 'its', 'would', 'already', 'twelve', 'nor', 'n’t', 'mostly', '’ve', 'if', 'first', 'up', 'unless', 'whence', 'empty', 'same', 'last', 'ca', 'go', 'least', 'much', 'where', 'hundred', 'latter', 'various', 'make', 'eight', "'d", 'your', 'until', 'himself', 'beside', 'well', '’d', 'always', 'at', 'none', '‘re', '‘ll', 'throughout', 'regarding', '’m', 'thereupon', 'meanwhile', 'becomes', 'few', 'is', 'whereafter', 'ours', 'whole', 'whom', 'though', 'seems', 'she', 'might', 'whose', 'beforehand', 'nine', 'seeming', 'cannot', 'with', 'after', 'do', 'i', 'must', 'please', 'further', 'anything', 'became', 'forty', 'say', 'around', 'ourselves', 'often', 'had', 'am', 'be', 'him', 'thence', 'among', "'ve", '‘d', 'back', 'wherein', 'myself', 'yet', 'about', 'afterwards', 'seem', '’ll', 'besides', 'what', 'nobody', 'own', 'should', 'the', 'upon', 'sixty', 'an', 'he', 'without', 'else', 'take', 'rather', "'s", 'all', 'are', 'elsewhere', 'between', 'yours', 'show', 'whither', 'amongst', 'somehow', 'this', '‘s', 'noone', 'by', 'indeed', "'ll", 'before', 'enough', 'so', 'could', 'onto', 'seemed', 'part', 'made', 'eleven', 'to', 'such'}
# 326

# %%
print(nlp.vocab['myself'].is_stop)
print(nlp.vocab['mystery'].is_stop)
# Out:
# True
# False

# %%
print (nlp.vocab['btw'].is_stop) #print False
# Out:
# False

# %%
nlp.Defaults.stop_words.add('btw')

nlp.vocab['btw'].is_stop = True # You must update the is_stop flag for the word you added

print (nlp.vocab['btw'].is_stop)
# Out:
# True

# %%
nlp.Defaults.stop_words.remove('beyond')
nlp.vocab['beyond'].is_stop = False

print(nlp.vocab['beyond'].is_stop)
# Out:
# False

# %% [markdown]
# ### Stop words in NLTK

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jaber/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
print(len(stop_words))
# Out:
# 198

# %%
print(stop_words)
# Out:
# {'their', 'below', 'she', "they're", 'again', 'doing', 'out', 'no', 'under', 'has', 'were', "won't", 'down', 'too', 'after', "isn't", 'll', 'with', 'yourself', 'do', 'i', 'these', 'been', "mightn't", "he's", 'and', 'further', 'there', 'off', 'over', "they'd", 'than', "hadn't", "he'll", 'ourselves', "needn't", 'once', 'why', 'on', "don't", "weren't", 'did', 'had', 'am', 'me', 'be', 'herself', 've', 'him', 'being', "mustn't", 'my', 'can', 'myself', 'those', 'from', 'hasn', 'theirs', 'y', 'does', 'during', 'hers', 'which', 'you', 'most', 'mustn', "we're", "i'll", "we'll", 'any', 'about', 'its', "couldn't", 'some', "i'm", "shouldn't", 'just', 'here', 'nor', 'how', 'our', 'what', 'couldn', "it's", 'own', 'shan', 'should', 'won', "you'd", 'the', "i'd", 'that', 'if', 'each', 'don', 'wouldn', 'itself', 'having', 'them', "he'd", 'up', "that'll", 'd', 'needn', 'into', 'an', 'he', 'now', 'same', 'but', "haven't", "it'll", 'very', 'where', "i've", 'above', 'other', "wouldn't", 'your', 're', 'didn', "you've", 'wasn', 'until', "she'll", 'all', 'hadn', 'who', 'are', 'himself', "shan't", 'weren', 'yourselves', 'aren', "hasn't", 'mightn', 'ain', 'themselves', "doesn't", "didn't", 'we', "it'd", 'against', "you'll", 'between', "wasn't", 'yours', 'haven', 'it', 'at', 'both', 'while', 'o', "they'll", 'ma', "she's", "we've", "you're", 'more', "she'd", 'only', 'as', 'her', 'this', 'm', 'by', 'then', "they've", 'because', 'when', 'isn', "should've", 'few', 'not', 'doesn', 't', "we'd", 'for', 'is', 'have', 'of', 'in', 'they', 'before', 'was', 'or', 'a', "aren't", 'through', 'shouldn', 'ours', 'so', 'whom', 'his', 'will', 's', 'to', 'such'}

# %% [markdown]
# _________________________________________________________________________________________________________

# %% [markdown]
# # Text pre-processing and Regular Expression Tasks:

# %% [markdown]
# # Task 1:
# To make you understand better about the need of text pre-processing. We will do a small project. In this project, you need to find how many hashtags and the top 10 hashtags used in the dataset.
#
# The dataset is about people tweets about apple company on Twitter. You can find the dataset here:
#
# https://www.kaggle.com/datasets/seriousran/appletwittersentimenttexts

# %%
import pandas as pd
import re
from collections import Counter

df = pd.read_csv('apple_twitter_sentiment_texts.csv')
print(df.shape)
df.head()
# Out:
# (1630, 2)
#                                                 text  sentiment
# 0  Wow. Yall needa step it up @Apple RT @heynyla:...         -1
# 1  What Happened To Apple Inc?   http://t.co/FJEX...          0
# 2  Thank u @apple I can now compile all of the pi...          1
# 3  The oddly uplifting story of the Apple co-foun...          0
# 4  @apple can i exchange my iphone for a differen...          0

# %% [markdown]
# ### Step 1: Text pre-processing
#
# Lower-case the tweet text before extracting hashtags, so that `#Apple` and `#apple` are counted as the same hashtag.

# %%
df['clean_text'] = df['text'].str.lower()
df[['text', 'clean_text']].head()
# Out:
#                                                 text  \
# 0  Wow. Yall needa step it up @Apple RT @heynyla:...
# 1  What Happened To Apple Inc?   http://t.co/FJEX...
# 2  Thank u @apple I can now compile all of the pi...
# 3  The oddly uplifting story of the Apple co-foun...
# 4  @apple can i exchange my iphone for a differen...
#
#                                           clean_text
# 0  wow. yall needa step it up @apple rt @heynyla:...
# 1  what happened to apple inc?   http://t.co/fjex...
# 2  thank u @apple i can now compile all of the pi...
# 3  the oddly uplifting story of the apple co-foun...
# 4  @apple can i exchange my iphone for a differen...

# %% [markdown]
# ### Step 2: Extract hashtags using a regular expression
#
# A hashtag starts with `#` followed by one or more word characters (letters, digits, underscore). We use `re.findall(r"#\w+", text)` on every tweet to pull out all its hashtags, then flatten the results into a single list.

# %%
hashtag_pattern = re.compile(r"#\w+")

df['hashtags'] = df['clean_text'].apply(lambda t: hashtag_pattern.findall(t))

all_hashtags = [tag for tags in df['hashtags'] for tag in tags]

print("Total number of hashtags found:", len(all_hashtags))
print("Number of unique hashtags:", len(set(all_hashtags)))
# Out:
# Total number of hashtags found: 1616
# Number of unique hashtags: 555

# %% [markdown]
# ### Step 3: Top 10 most frequent hashtags
#
# Use `collections.Counter` to count how many times each hashtag appears, then take the 10 most common.

# %%
hashtag_counts = Counter(all_hashtags)
top_10_hashtags = hashtag_counts.most_common(10)

print("Top 10 hashtags:")
for rank, (tag, count) in enumerate(top_10_hashtags, start=1):
    print(f"{rank}. {tag}: {count}")
# Out:
# Top 10 hashtags:
# 1. #aapl: 400
# 2. #apple: 162
# 3. #iphone: 38
# 4. #december: 37
# 5. #iphone6: 29
# 6. #stocks: 15
# 7. #ipad: 14
# 8. #iphone6plus: 13
# 9. #iphone6s: 13
# 10. #tech: 12

# %%
import matplotlib.pyplot as plt

tags, counts = zip(*top_10_hashtags)

plt.figure(figsize=(10, 5))
plt.bar(tags, counts, color='steelblue')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Hashtag')
plt.ylabel('Frequency')
plt.title('Top 10 Hashtags in Apple Twitter Sentiment Dataset')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Task 2: Using re.compile()
# Given the following text: "This year is 2021"
#
# Write a Python program that:
#
# 1. Use re.compile() to create a regular expression pattern that matches one or more digits.
# 2. Print the type of the compiled pattern.
# 3. Use the compiled pattern to replace 2021 with 2022.
# 4. Print the updated text.
# 5. Briefly explain what re.compile() does and why it is useful when working with regular expressions.

# %%
import re

text = "This year is 2021"

pattern = re.compile(r"\d+")
print(type(pattern))

updated_text = pattern.sub("2022", text)
print(updated_text)
# Out:
# <class 're.Pattern'>
# This year is 2022

# %% [markdown]
# **What `re.compile()` does and why it's useful:** it pre-compiles a regular expression pattern into a reusable `re.Pattern` object instead of a plain string. That object exposes the same methods as the `re` module (`.search()`, `.match()`, `.findall()`, `.sub()`, `.split()`, ...) already bound to that pattern. Compiling is useful because (1) the pattern only needs to be parsed once, so reusing it many times (e.g. inside a loop over a large dataset) is faster than calling `re.sub(pattern, ...)` repeatedly, which has to compile the pattern internally on every call; and (2) it makes code cleaner and more readable when the same pattern is applied in several places.

# %% [markdown]
# # Task 3: Using re.split()
# Given the following text = "a 11 b 2 3 c 4"
#
# Write a Python program that:
#
# 1. Use re.split() with a regular expression pattern to split the text whenever one or more digits appear.
# 2. Print the resulting list.
# 3. Briefly explain: what re.split() does.

# %%
import re

text = "a 11 b 2 3 c 4"

result = re.split(r"\d+", text)
print(result)
# Out:
# ['a ', ' b ', ' ', ' c ', '']

# %% [markdown]
# **What `re.split()` does:** it scans the string for every match of the given pattern (here `\d+`, one or more consecutive digits) and splits the string at each match, returning a list of the substrings found between the matches. The matched digit runs themselves are removed and do not appear in the result — only the text *between* them does.

# %% [markdown]
# # Task 4: Tokenization Using spaCy
#
# Processes the following sentence: "I'm enjoying the NLP course!"
#
# Write a Python program that:
#
# 1. Use spaCy library and load the small English model en_core_web_sm.
# 2. Iterate through the text and print each token on a separate line.
# 3. Briefly explain: What spacy.load() does.
# 5. Tokenize the same text using nltk library and notice the differences compared to spaCy output.

# %% [markdown]
# ### Step 1: Tokenize with spaCy

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

text = "I'm enjoying the NLP course!"
doc = nlp(text)

print('spaCy tokens:')
for token in doc:
    print(token)
# Out:
# spaCy tokens:
# I
# 'm
# enjoying
# the
# NLP
# course
# !

# %% [markdown]
# **What `spacy.load()` does:** it loads a trained spaCy language pipeline (here the small English model `en_core_web_sm`) from disk into memory and returns an `nlp` object. That object bundles a tokenizer together with the pipeline components the model was trained with (tagger, parser, NER, lemmatizer, etc.), so calling `nlp(text)` both tokenizes the text and runs it through the whole pipeline, giving each token rich linguistic annotations, not just a plain string split.

# %% [markdown]
# ### Step 2: Tokenize the same sentence with NLTK and compare

# %%
import nltk

nltk_tokens = nltk.word_tokenize(text)
print('NLTK tokens:')
print(nltk_tokens)

spacy_tokens = [token.text for token in doc]
print()
print('spaCy tokens:', spacy_tokens)
print('NLTK tokens: ', nltk_tokens)
print('Same result?', spacy_tokens == nltk_tokens)
# Out:
# NLTK tokens:
# ['I', "'m", 'enjoying', 'the', 'NLP', 'course', '!']
#
# spaCy tokens: ['I', "'m", 'enjoying', 'the', 'NLP', 'course', '!']
# NLTK tokens:  ['I', "'m", 'enjoying', 'the', 'NLP', 'course', '!']
# Same result? True

# %% [markdown]
# **Differences noticed:** for this sentence both tokenizers actually split "I'm" into `I` + `'m`, punctuation `!` as its own token, and "course" as a separate token — so the output lists are identical here. In general, though, spaCy and NLTK don't always agree: spaCy's tokenizer uses rule-based exceptions plus prefix/suffix/infix rules tied to the loaded model and is tightly integrated with the rest of the pipeline (POS tags, dependency parse, etc.), while NLTK's `word_tokenize` uses the Penn Treebank tokenization rules. On more complex text (contractions, hyphenated words, URLs, emojis) they can produce different token boundaries.
